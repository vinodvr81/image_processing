# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pack = cv2.imread("dog_backpack.png")

# %%
plt.imshow(pack)

# %%
pack_rgb = cv2.cvtColor(pack, cv2.COLOR_BGR2RGB)
plt.imshow(pack_rgb)

# %%
new_pack = pack
new_flip_pack = cv2.flip(new_pack,0)
plt.imshow(new_flip_pack)

# %%
cv2.rectangle(pack_rgb,pt1=(200,380),pt2=(600,700),color=(255,0,0),thickness=10)
plt.imshow(pack_rgb)

# %%
plt.imshow(pack)

# %%
plt.imshow(pack_rgb)

# %%
water_img = cv2.imread('watermark_no_copy.png')

# %%
cv2.putText(pack_rgb,text='Hello Vinod Vukkalam',org=(10,245), fontFace=cv2.FONT_ITALIC,fontScale= 2,color=(255,0,0),thickness=2,lineType=cv2.LINE_AA)
plt.imshow(pack_rgb)

# %%
plt.imshow(pack_rgb)

# %%
pack_rgb.shape
# Out:
# (1401, 934, 3)

# %%
cv2.putText(water_img,text='Hello Vinod Vukkalam',org=(10,245), fontFace=cv2.FONT_ITALIC,fontScale= 2,color=(255,0,0),thickness=2,lineType=cv2.LINE_AA)
plt.imshow(water_img)
